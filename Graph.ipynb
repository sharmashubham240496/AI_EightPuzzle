# %% [markdown]
# NAME : SHUBHAM SHARMA
#
# SID : 862394567

# %%
data1 = [[0,1,0],[5,6,2],[22,18,4],[296,180,8],[1885,1133,12],[13442,6596,16],[52840,17894,20],[119599,241884,24]]
data2 = [[0,1,0],[2,3,2],[4,6,4],[18,16,8],[119, 84,12],[658,413,16],[2704,1611,20],[13624,7039,24]]
data3 = [[0,1,0],[2,3,2],[4,6,4],[12,12,8],[36, 28,12],[118,114,16],[374,239,20],[1777,1007,24]]

# %%
import matplotlib.pyplot as plt

data1 = [[0,1,0],[5,6,2],[22,18,4],[296,180,8],[1885,1133,12],[13442,6596,16],[52840,17894,20]]#,[13442,6596,16],[52840,17894,20],[119599,241884,24]
data2 = [[0,1,0],[2,3,2],[4,6,4],[18,16,8],[119, 84,12],[658,413,16],[2704,1611,20],[13624,7039,24]]
data3 = [[0,1,0],[2,3,2],[4,6,4],[12,12,8],[36, 28,12],[118,114,16],[374,239,20],[1777,1007,24]]



x1 = [i[2] for i in data1]
y1 = [i[1] for i in data1]
x2 = [i[2] for i in data2]
y2 = [i[1] for i in data2]
x3 = [i[2] for i in data3]
y3 = [i[1] for i in data3]


plt.plot(x1, y1, label='Uniform Cost Search')
plt.plot(x2, y2, label='A* Misplaced tile')
plt.plot(x3, y3, label='A* Manhattan')
plt.xlabel('Solution Depth')
plt.ylabel('Nodes Expanded')
plt.title('Plotting Nodes Expanded and Solution Depth')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

data1 = [[0,1,0],[5,6,2],[22,18,4],[296,180,8],[1885,1133,12],[13442,6596,16],[52840,17894,20]]#,[13442,6596,16],[52840,17894,20],[119599,241884,24]
data2 = [[0,1,0],[2,3,2],[4,6,4],[18,16,8],[119, 84,12],[658,413,16],[2704,1611,20],[13624,7039,24]]
data3 = [[0,1,0],[2,3,2],[4,6,4],[12,12,8],[36, 28,12],[118,114,16],[374,239,20],[1777,1007,24]]



x1 = [i[2] for i in data1]
y1 = [i[0] for i in data1]
x2 = [i[2] for i in data2]
y2 = [i[0] for i in data2]
x3 = [i[2] for i in data3]
y3 = [i[0] for i in data3]


plt.plot(x1, y1, label='Uniform Cost Search')
plt.plot(x2, y2, label='A* Misplaced tile')
plt.plot(x3, y3, label='A* Manhattan')
plt.xlabel('Solution Depth')
plt.ylabel('Maximum Size of queue')
plt.title('Plotting Maximum Size of queue and Solution Depth')
plt.legend()
plt.show()
